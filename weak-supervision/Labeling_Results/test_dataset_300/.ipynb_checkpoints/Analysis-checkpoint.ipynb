# %%
import json
from collections import Counter, defaultdict
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define your provided code functions

def load_json(file_path):
    with open(file_path, 'r') as f:
        return json.load(f)

def find_shared_tiles_and_agreement(labeler_data, threshold):
    common_tiles = set.intersection(*[set(labeler.keys()) for labeler in labeler_data.values()])
    total_common_tiles = len(common_tiles)
    agreed_tiles = 0
    common_tile_labels = {}

    for tile in common_tiles:
        tile_labels = []
        for labeler, data in labeler_data.items():
            first_image = next(iter(data[tile]))
            label = data[tile][first_image]['label']
            tile_labels.append(label)
        common_tile_labels[tile] = tile_labels
        label_count = Counter(tile_labels)
        most_common_label, most_common_count = label_count.most_common(1)[0]
        if most_common_count >= threshold:
            agreed_tiles += 1
    
    agreement_percentage = (agreed_tiles / total_common_tiles) * 100 if total_common_tiles > 0 else 0
    print(f"\nTotal common tiles: {total_common_tiles}")
    print(f"Number of tiles where at least {threshold} labelers agree: {agreed_tiles}")
    print(f"Percentage of agreement: {agreement_percentage:.2f}%")
    
    return common_tile_labels

def process_labeler_files(file_paths, threshold):
    labeler_data = {}
    for file_path in file_paths:
        labeler_name = file_path.split('_')[0]
        labeler_data[labeler_name] = load_json(file_path)
    common_tile_labels = find_shared_tiles_and_agreement(labeler_data, threshold)
    return labeler_data, common_tile_labels

# %%
# List your JSON file paths here
file_paths = ['Ali_labels.json', 
              'Brian_labels.json',
             'David_labels.json', 
             'Dr.Lory_labels.json',
             'Krystal_labels.json',
             'Pankaj_labels.json',
             'Parth_labels.json',
             'Yizheng_labels.json']
threshold = 5  # Set an example threshold

# Process files to get labeler data and shared tile labels
labeler_data, common_tile_labels = process_labeler_files(file_paths, threshold)

# Prepare data for cross-correlation analysis
labeler_names = list(labeler_data.keys())
num_labelers = len(labeler_names)
correlation_matrix = np.zeros((num_labelers, num_labelers))

# Calculate cross-correlation between labelers
for i, labeler1 in enumerate(labeler_names):
    for j, labeler2 in enumerate(labeler_names):
        if i == j:
            correlation_matrix[i, j] = 1.0  # Perfect correlation with oneself
        else:
            agreement_count = sum(1 for tile in common_tile_labels 
                                  if common_tile_labels[tile][i] == common_tile_labels[tile][j])
            correlation_matrix[i, j] = agreement_count / len(common_tile_labels)

# Create a DataFrame for easier handling in visualization
correlation_df = pd.DataFrame(correlation_matrix, index=labeler_names, columns=labeler_names)

# Plot the cross-correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_df, annot=True, cmap="coolwarm", cbar=True, square=True, 
            linewidths=0.5, linecolor='gray', fmt=".2f",vmin=0, vmax=1)
plt.title("Cross-Correlation of Label Agreement Among Labelers")
# plt.savefig('CC_raw.png')
plt.show()
# Out:
# Total common tiles: 99
# Number of tiles where at least 5 labelers agree: 60
# Percentage of agreement: 60.61%

# %%
import json
from collections import Counter, defaultdict
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define your provided code functions with an added transformation step

def load_json(file_path):
    with open(file_path, 'r') as f:
        return json.load(f)

def transform_labels(label):
    # Transform specific labels as requested
    if label == '3':
        return '4'
    elif label == '1':
        return '0'
    else:
        return label

def find_shared_tiles_and_agreement(labeler_data, threshold):
    # Find common tiles and apply transformation
    common_tiles = set.intersection(*[set(labeler.keys()) for labeler in labeler_data.values()])
    total_common_tiles = len(common_tiles)
    agreed_tiles = 0
    common_tile_labels = {}

    for tile in common_tiles:
        tile_labels = []
        for labeler, data in labeler_data.items():
            first_image = next(iter(data[tile]))
            # Apply label transformation here
            label = transform_labels(data[tile][first_image]['label'])
            tile_labels.append(label)
        common_tile_labels[tile] = tile_labels
        label_count = Counter(tile_labels)
        most_common_label, most_common_count = label_count.most_common(1)[0]
        if most_common_count >= threshold:
            agreed_tiles += 1
    
    agreement_percentage = (agreed_tiles / total_common_tiles) * 100 if total_common_tiles > 0 else 0
    print(f"\nTotal common tiles: {total_common_tiles}")
    print(f"Number of tiles where at least {threshold} labelers agree: {agreed_tiles}")
    print(f"Percentage of agreement: {agreement_percentage:.2f}%")
    
    return common_tile_labels

def process_labeler_files(file_paths, threshold):
    labeler_data = {}
    for file_path in file_paths:
        labeler_name = file_path.split('_')[0]
        labeler_data[labeler_name] = load_json(file_path)
    # Apply label transformation to common tiles
    common_tile_labels = find_shared_tiles_and_agreement(labeler_data, threshold)
    return labeler_data, common_tile_labels

# List your JSON file paths here
file_paths = ['Ali_labels.json', 
              'Brian_labels.json',
             'David_labels.json', 
             'Dr.Lory_labels.json',
             'Krystal_labels.json',
             'Pankaj_labels.json',
             'Parth_labels.json',
             'Yizheng_labels.json']
threshold = 6  # Set an example threshold

# Process files to get labeler data and transformed shared tile labels
labeler_data, common_tile_labels = process_labeler_files(file_paths, threshold)

# Prepare data for cross-correlation analysis
labeler_names = list(labeler_data.keys())
num_labelers = len(labeler_names)
correlation_matrix = np.zeros((num_labelers, num_labelers))

# Calculate cross-correlation between labelers using transformed labels
for i, labeler1 in enumerate(labeler_names):
    for j, labeler2 in enumerate(labeler_names):
        if i == j:
            correlation_matrix[i, j] = 1  # Perfect correlation with oneself
        else:
            # Count the transformed label matches for cross-correlation
            agreement_count = sum(1 for tile in common_tile_labels 
                                  if transform_labels(common_tile_labels[tile][i]) == transform_labels(common_tile_labels[tile][j]))
            correlation_matrix[i, j] = agreement_count / len(common_tile_labels) if len(common_tile_labels) > 0 else 0

# Create a DataFrame for easier handling in visualization
correlation_df = pd.DataFrame(correlation_matrix, index=labeler_names, columns=labeler_names)

# Plot the cross-correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_df, annot=True, cmap="coolwarm", cbar=True, square=True, 
            linewidths=0.5, linecolor='gray', fmt=".2f",vmin=0, vmax=1)
plt.title("Cross-Correlation of Label Agreement Among Labelers (Modified Labels)")
# plt.savefig('CC_tol.png')
plt.show()
# Out:
# Total common tiles: 99
# Number of tiles where at least 6 labelers agree: 77
# Percentage of agreement: 77.78%

# %%
import json
from collections import Counter, defaultdict
import pandas as pd

# Define the helper functions
def load_json(file_path):
    with open(file_path, 'r') as f:
        return json.load(f)

def transform_labels(label):
    if label == '3':
        return '4'
    elif label == '1':
        return '0'
    else:
        return label

def calculate_agreement(labeler_data, threshold, use_transformed_labels=False):
    # Find common tiles across all labelers
    common_tiles = set.intersection(*[set(labeler.keys()) for labeler in labeler_data.values()])
    agreed_tiles = 0

    for tile in common_tiles:
        tile_labels = []
        for labeler, data in labeler_data.items():
            first_image = next(iter(data[tile]))
            # Optionally transform labels if specified
            label = data[tile][first_image]['label']
            if use_transformed_labels:
                label = transform_labels(label)
            tile_labels.append(label)
        
        # Count the frequency of each label
        label_count = Counter(tile_labels)
        most_common_label, most_common_count = label_count.most_common(1)[0]

        # Check if the most common label meets the threshold for agreement
        if most_common_count >= threshold:
            agreed_tiles += 1

    return f'{((agreed_tiles / len(common_tiles))*100):.2f}'

def process_labeler_files(file_paths):
    labeler_data = {}
    for file_path in file_paths:
        labeler_name = file_path.split('_')[0]
        labeler_data[labeler_name] = load_json(file_path)
    return labeler_data

# List your JSON file paths here
file_paths = ['Ali_labels.json', 
              'Brian_labels.json', 
             'Dr.Lory_labels.json',
             'Krystal_labels.json',
             'Pankaj_labels.json',
             'Parth_labels.json',
             'Yizheng_labels.json']

# Process files to get labeler data
labeler_data = process_labeler_files(file_paths)

# Initialize a list to store agreement results
agreement_results = []

# Calculate agreement for thresholds from 2 to 8
for threshold in range(2, 9):
    # Agreement without transformation
    original_agreement = calculate_agreement(labeler_data, threshold, use_transformed_labels=False)
    # Agreement with transformation
    transformed_agreement = calculate_agreement(labeler_data, threshold, use_transformed_labels=True)
    # Append results to the list
    agreement_results.append({
        "Number of Labelers Threshold": threshold,
        "Agreement (Original Labels)": original_agreement,
        "Agreement (Transformed Labels)": transformed_agreement
    })

# Convert the list of results into a DataFrame
agreement_table = pd.DataFrame(agreement_results)
agreement_table.set_index("Number of Labelers Threshold", inplace=True)

# Display the results table
display(agreement_table)
# Out:
#                              Agreement (Original Labels)  \
# Number of Labelers Threshold
# 2                                                 100.00
# 3                                                  97.98
# 4                                                  75.76
# 5                                                  59.60
# 6                                                  38.38
# 7                                                  25.25
# 8                                                   0.00
#
#                              Agreement (Transformed Labels)
# Number of Labelers Threshold
# 2                                                    100.00
# 3                                                    100.00
# 4                                                     96.97
# 5                                                     83.84
# 6                                                     71.72
# 7                                                     45.45
# 8                                                      0.00

# %%
import json
from collections import Counter, defaultdict
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define your provided code functions

def load_json(file_path):
    with open(file_path, 'r') as f:
        return json.load(f)

def label_similarity(label1, label2):
    # Similarity function based on absolute difference
    # return 1 / (1 + abs(int(label1) - int(label2)))
    S = 1 - (abs(int(label1) - int(label2))/4)

    return S

def find_shared_tiles_and_agreement(labeler_data, threshold):
    common_tiles = set.intersection(*[set(labeler.keys()) for labeler in labeler_data.values()])
    total_common_tiles = len(common_tiles)
    agreed_tiles = 0
    common_tile_labels = {}

    for tile in common_tiles:
        tile_labels = []
        for labeler, data in labeler_data.items():
            first_image = next(iter(data[tile]))
            label = data[tile][first_image]['label']
            tile_labels.append(label)
        common_tile_labels[tile] = tile_labels
        label_count = Counter(tile_labels)
        most_common_label, most_common_count = label_count.most_common(1)[0]
        if most_common_count >= threshold:
            agreed_tiles += 1
    
    agreement_percentage = (agreed_tiles / total_common_tiles) * 100 if total_common_tiles > 0 else 0
    print(f"\nTotal common tiles: {total_common_tiles}")
    print(f"Number of tiles where at least {threshold} labelers agree: {agreed_tiles}")
    print(f"Percentage of agreement: {agreement_percentage:.2f}%")
    
    return common_tile_labels

def process_labeler_files(file_paths, threshold):
    labeler_data = {}
    for file_path in file_paths:
        labeler_name = file_path.split('_')[0]
        labeler_data[labeler_name] = load_json(file_path)
    common_tile_labels = find_shared_tiles_and_agreement(labeler_data, threshold)
    return labeler_data, common_tile_labels

# List your JSON file paths here
file_paths = ['Ali_labels.json', 
              'Brian_labels.json',
             'David_labels.json', 
             'Dr.Lory_labels.json',
             'Krystal_labels.json',
             'Pankaj_labels.json',
             'Parth_labels.json',
             'Yizheng_labels.json']
threshold = 5  # Set an example threshold

# Process files to get labeler data and shared tile labels
labeler_data, common_tile_labels = process_labeler_files(file_paths, threshold)

# Prepare data for weighted cross-correlation analysis
labeler_names = list(labeler_data.keys())
num_labelers = len(labeler_names)
correlation_matrix = np.zeros((num_labelers, num_labelers))

# Calculate weighted cross-correlation between labelers
for i, labeler1 in enumerate(labeler_names):
    for j, labeler2 in enumerate(labeler_names):
        if i == j:
            correlation_matrix[i, j] = 1  # Perfect correlation with oneself
        else:
            similarity_scores = []
            for tile in common_tile_labels:
                label1 = common_tile_labels[tile][i]
                label2 = common_tile_labels[tile][j]
                # Calculate similarity between the labels and add to list
                similarity_scores.append(label_similarity(label1, label2))
            
            # Calculate average similarity for this pair of labelers
            correlation_matrix[i, j] = np.mean(similarity_scores) if similarity_scores else 0

# Create a DataFrame for easier handling in visualization
correlation_df = pd.DataFrame(correlation_matrix, index=labeler_names, columns=labeler_names)

# Plot the weighted cross-correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_df, annot=True, cmap="coolwarm", cbar=True, square=True, 
            linewidths=0.5, linecolor='gray', fmt=".2f",vmin=0, vmax=1)
plt.title("Weighted Cross-Correlation of Label Agreement Among Labelers")
# plt.savefig('WCC.png')
plt.show()
# Out:
# Total common tiles: 99
# Number of tiles where at least 5 labelers agree: 60
# Percentage of agreement: 60.61%

# %%
import json
from collections import Counter, defaultdict
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns




# Load JSON files as before
def load_json(file_path):
    with open(file_path, 'r') as f:
        return json.load(f)

def find_shared_tiles_and_agreement(labeler_data):
    # Find common tiles across all labelers
    common_tiles = set.intersection(*[set(labeler.keys()) for labeler in labeler_data.values()])
    common_tile_labels = {labeler: [] for labeler in labeler_data.keys()}
    
    # Collect labels for each common tile by each labeler
    for tile in common_tiles:
        for labeler, data in labeler_data.items():
            first_image = next(iter(data[tile]))
            label = data[tile][first_image]['label']
            common_tile_labels[labeler].append(label)
    
    return common_tile_labels

def process_labeler_files(file_paths):
    labeler_data = {}
    for file_path in file_paths:
        labeler_name = file_path.split('_')[0]
        labeler_data[labeler_name] = load_json(file_path)
    common_tile_labels = find_shared_tiles_and_agreement(labeler_data)
    return common_tile_labels

# List your JSON file paths here
file_paths = ['Ali_labels.json', 
              'Brian_labels.json',
             'David_labels.json', 
             'Dr.Lory_labels.json',
             'Krystal_labels.json',
             'Pankaj_labels.json',
             'Parth_labels.json',
             'Yizheng_labels.json']

# Process files to get the label data for common tiles
common_tile_labels = process_labeler_files(file_paths)

# Set the categorical order for labels (ensures same order for all plots)
label_order = [0, 1, 2, 3, 4]

# Plot histograms for each labeler
plt.figure(figsize=(15, 10))

for i, (labeler, labels) in enumerate(common_tile_labels.items()):
    plt.subplot(2, (len(common_tile_labels) + 1) // 2, i + 1)
    # Convert to DataFrame with a categorical type for consistent ordering
    df = pd.DataFrame({'Label': labels})
    # df['Label'] = pd.Categorical(df['Label'], categories=label_order, ordered=True)
    # Plot with seaborn countplot
    sns.countplot(data=df, x='Label', order=label_order)
    plt.title(f"Label Distribution for {labeler}")
    plt.xlabel("Label")
    plt.ylabel("Count")

plt.tight_layout()
# plt.savefig('label_hists.png')
plt.show()

# %%
import json
from collections import Counter, defaultdict


def transform_labels(label):
    if label == '3':
        return '4'
    elif label == '1':
        return '0'
    else:
        return label


# Load JSON files as before
def load_json(file_path):
    with open(file_path, 'r') as f:
        return json.load(f)

def categorize_tiles(labeler_data):
    # Find common and uncommon tiles
    all_tiles = set(tile for data in labeler_data.values() for tile in data.keys())
    common_tiles = set.intersection(*[set(labeler.keys()) for labeler in labeler_data.values()])
    uncommon_tiles = all_tiles - common_tiles
    
    tile_agreement_dict = []

    # Process common tiles
    for tile in common_tiles:
        tile_labels = []
        labeler_by_label = defaultdict(list)
        
        for labeler, data in labeler_data.items():
            first_image = next(iter(data[tile]))
            label = data[tile][first_image]['label']
            tile_labels.append(label)
            labeler_by_label[label].append(labeler)
        
        # Count occurrences of each label for the tile
        label_count = Counter(tile_labels)

        # Check for labels agreed upon by more than 6 labelers
        for label, count in label_count.items():
            if count >= 6:
                tile_agreement_dict.append({
                    "tile_number": tile,
                    "label": label,
                    "labelers": labeler_by_label[label]
                })
                break  # Skip to the next tile if we find a label with more than 6 agreements

    # Process uncommon tiles
    for tile in uncommon_tiles:
        tile_labels = []
        labeler_by_label = defaultdict(list)
        
        for labeler, data in labeler_data.items():
            if tile in data:
                first_image = next(iter(data[tile]))
                label = data[tile][first_image]['label']
                tile_labels.append(label)
                labeler_by_label[label].append(labeler)
        
        # Count occurrences of each label for the tile
        label_count = Counter(tile_labels)

        # Check for labels agreed upon by exactly 2 labelers
        for label, count in label_count.items():
            if count == 2:
                tile_agreement_dict.append({
                    "tile_number": tile,
                    "label": label,
                    "labelers": labeler_by_label[label]
                })
                break  # Store only the first label with exactly 2 agreements

    return tile_agreement_dict

def process_labeler_files(file_paths):
    labeler_data = {}
    for file_path in file_paths:
        labeler_name = file_path.split('_')[0]
        labeler_data[labeler_name] = load_json(file_path)
    tile_agreement_dict = categorize_tiles(labeler_data)
    return tile_agreement_dict

# List your JSON file paths here
file_paths = ['Ali_labels.json', 
              'Brian_labels.json',
             'David_labels.json', 
             'Dr.Lory_labels.json',
             'Krystal_labels.json',
             'Pankaj_labels.json',
             'Parth_labels.json',
             'Yizheng_labels.json']

# Process files and get the dictionary of tiles with agreements
tile_agreement_dict = process_labeler_files(file_paths)

# Display the result
for entry in tile_agreement_dict:
    print(f"Tile Number: {entry['tile_number']}, Label: {entry['label']}, Labelers: {entry['labelers']}")
# Out:
# Tile Number: 1085, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1050, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 883, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 681, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 795, Label: 0, Labelers: ['Ali', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth']
# Tile Number: 721, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 885, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 632, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 647, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1117, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 529, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 476, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth']
# Tile Number: 635, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 852, Label: 0, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 31, Label: 0, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 302, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1110, Label: 0, Labelers: ['Ali', 'David', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 703, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 695, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 116, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 597, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Parth', 'Yizheng']
# Tile Number: 495, Label: 2, Labelers: ['Ali', 'Brian', 'David', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 136, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 577, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth']
# Tile Number: 217, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Yizheng']
# Tile Number: 522, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 618, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Yizheng']
# Tile Number: 496, Label: 2, Labelers: ['Ali', 'Brian', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1036, Label: 0, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 722, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Yizheng']
# Tile Number: 189, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 685, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 359, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1032, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Parth', 'Yizheng']
# Tile Number: 619, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Yizheng']
# Tile Number: 50, Label: 1, Labelers: ['Brian', 'David', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1043, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 369, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 223, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 552, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 812, Label: 0, Labelers: ['Ali', 'David', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1105, Label: 0, Labelers: ['Ali', 'David', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 464, Label: 2, Labelers: ['Ali', 'Brian', 'David', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 816, Label: 4, Labelers: ['Brian', 'David']
# Tile Number: 98, Label: 0, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 249, Label: 0, Labelers: ['David', 'Krystal']
# Tile Number: 482, Label: 2, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 740, Label: 0, Labelers: ['Ali', 'Krystal']
# Tile Number: 309, Label: 2, Labelers: ['David', 'Krystal']
# Tile Number: 826, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 759, Label: 0, Labelers: ['David', 'Dr.Lory']
# Tile Number: 224, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 411, Label: 3, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 561, Label: 3, Labelers: ['Ali', 'Brian']
# Tile Number: 344, Label: 0, Labelers: ['Parth', 'Yizheng']
# Tile Number: 21, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 427, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 264, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 1038, Label: 0, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 349, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 83, Label: 0, Labelers: ['David', 'Krystal']
# Tile Number: 600, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 1044, Label: 0, Labelers: ['Pankaj', 'Parth']
# Tile Number: 534, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 1021, Label: 0, Labelers: ['David', 'Pankaj']
# Tile Number: 518, Label: 2, Labelers: ['Krystal', 'Parth']
# Tile Number: 111, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 916, Label: 4, Labelers: ['Ali', 'Brian']
# Tile Number: 606, Label: 3, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 271, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 723, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 914, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 715, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 615, Label: 4, Labelers: ['Ali', 'Brian']
# Tile Number: 1070, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 793, Label: 1, Labelers: ['Ali', 'Pankaj']
# Tile Number: 978, Label: 3, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 623, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 774, Label: 0, Labelers: ['David', 'Dr.Lory']
# Tile Number: 999, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 7, Label: 3, Labelers: ['Brian', 'Pankaj']
# Tile Number: 965, Label: 4, Labelers: ['Brian', 'David']
# Tile Number: 836, Label: 0, Labelers: ['David', 'Yizheng']
# Tile Number: 346, Label: 3, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 688, Label: 4, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 567, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 421, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 540, Label: 4, Labelers: ['Ali', 'Brian']
# Tile Number: 633, Label: 4, Labelers: ['Brian', 'David']
# Tile Number: 851, Label: 0, Labelers: ['Pankaj', 'Parth']
# Tile Number: 364, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 604, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 631, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 500, Label: 2, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 358, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 362, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 24, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 751, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 1067, Label: 0, Labelers: ['David', 'Pankaj']
# Tile Number: 214, Label: 3, Labelers: ['Brian', 'Yizheng']
# Tile Number: 450, Label: 4, Labelers: ['Krystal', 'Parth']
# Tile Number: 276, Label: 0, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 1140, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 73, Label: 3, Labelers: ['Parth', 'Yizheng']
# Tile Number: 5, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 4, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 513, Label: 0, Labelers: ['David', 'Dr.Lory']
# Tile Number: 520, Label: 0, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 1127, Label: 0, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 431, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 602, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 328, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 182, Label: 0, Labelers: ['Ali', 'Brian']
# Tile Number: 779, Label: 0, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 556, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 82, Label: 0, Labelers: ['Ali', 'Krystal']
# Tile Number: 244, Label: 0, Labelers: ['Ali', 'Yizheng']
# Tile Number: 124, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 798, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 813, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 320, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 1056, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 172, Label: 4, Labelers: ['Krystal', 'Parth']
# Tile Number: 918, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 404, Label: 3, Labelers: ['Parth', 'Yizheng']
# Tile Number: 902, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 131, Label: 0, Labelers: ['David', 'Parth']
# Tile Number: 108, Label: 0, Labelers: ['Brian', 'Yizheng']
# Tile Number: 380, Label: 2, Labelers: ['Brian', 'David']
# Tile Number: 563, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 1108, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 924, Label: 3, Labelers: ['Brian', 'Parth']
# Tile Number: 1149, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 428, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 1116, Label: 0, Labelers: ['Brian', 'Pankaj']
# Tile Number: 925, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 1057, Label: 0, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 436, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 884, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 153, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 235, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 1018, Label: 0, Labelers: ['Pankaj', 'Parth']
# Tile Number: 539, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 355, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 922, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 1125, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 127, Label: 0, Labelers: ['David', 'Parth']
# Tile Number: 415, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 988, Label: 1, Labelers: ['David', 'Parth']
# Tile Number: 1049, Label: 1, Labelers: ['Brian', 'David']
# Tile Number: 208, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 192, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 193, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 288, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 927, Label: 3, Labelers: ['Krystal', 'Parth']
# Tile Number: 921, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 758, Label: 0, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 160, Label: 3, Labelers: ['Brian', 'Yizheng']
# Tile Number: 255, Label: 0, Labelers: ['Ali', 'Krystal']
# Tile Number: 626, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 449, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 110, Label: 2, Labelers: ['Ali', 'Parth']
# Tile Number: 743, Label: 2, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 1035, Label: 0, Labelers: ['Brian', 'David']
# Tile Number: 882, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 292, Label: 0, Labelers: ['Ali', 'Yizheng']
# Tile Number: 733, Label: 0, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 797, Label: 0, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 895, Label: 3, Labelers: ['Ali', 'David']
# Tile Number: 578, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 519, Label: 0, Labelers: ['David', 'Krystal']
# Tile Number: 571, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 996, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 819, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 1077, Label: 0, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 739, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 467, Label: 2, Labelers: ['Brian', 'Yizheng']
# Tile Number: 1088, Label: 0, Labelers: ['Parth', 'Yizheng']
# Tile Number: 789, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 794, Label: 1, Labelers: ['Ali', 'David']
# Tile Number: 14, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 568, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 1071, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 838, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 33, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 966, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 625, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 1099, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 391, Label: 1, Labelers: ['Brian', 'Yizheng']
# Tile Number: 327, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 1007, Label: 3, Labelers: ['Brian', 'Yizheng']
# Tile Number: 679, Label: 4, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 820, Label: 3, Labelers: ['Brian', 'Krystal']
# Tile Number: 121, Label: 0, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 12, Label: 4, Labelers: ['Krystal', 'Parth']
# Tile Number: 732, Label: 0, Labelers: ['Pankaj', 'Parth']
# Tile Number: 832, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 670, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 551, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 742, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 1106, Label: 0, Labelers: ['Ali', 'Brian']
# Tile Number: 492, Label: 2, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 848, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 748, Label: 1, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 517, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 761, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 479, Label: 0, Labelers: ['Brian', 'David']
# Tile Number: 225, Label: 4, Labelers: ['David', 'Dr.Lory']
# Tile Number: 461, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 213, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 70, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 904, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 128, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 29, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 54, Label: 2, Labelers: ['Brian', 'Krystal']
# Tile Number: 100, Label: 0, Labelers: ['Brian', 'Parth']
# Tile Number: 473, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 973, Label: 3, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 765, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 1034, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 691, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 204, Label: 0, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 190, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 1003, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 233, Label: 4, Labelers: ['Ali', 'Brian']
# Tile Number: 558, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 250, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 1081, Label: 0, Labelers: ['Parth', 'Yizheng']
# Tile Number: 474, Label: 0, Labelers: ['David', 'Parth']
# Tile Number: 1051, Label: 0, Labelers: ['Ali', 'Krystal']
# Tile Number: 784, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 424, Label: 1, Labelers: ['Brian', 'Parth']
# Tile Number: 114, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 724, Label: 4, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 535, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 993, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 511, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 413, Label: 2, Labelers: ['David', 'Parth']
# Tile Number: 616, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 1118, Label: 1, Labelers: ['Brian', 'David']
# Tile Number: 104, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 196, Label: 4, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 1017, Label: 0, Labelers: ['David', 'Yizheng']
# Tile Number: 840, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 700, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 130, Label: 2, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 734, Label: 0, Labelers: ['David', 'Yizheng']
# Tile Number: 1096, Label: 0, Labelers: ['Parth', 'Yizheng']
# Tile Number: 786, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 622, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 719, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 1045, Label: 0, Labelers: ['Ali', 'Krystal']
# Tile Number: 373, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 842, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 125, Label: 0, Labelers: ['David', 'Krystal']
# Tile Number: 1138, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 636, Label: 3, Labelers: ['Ali', 'Brian']
# Tile Number: 462, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 667, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 890, Label: 3, Labelers: ['Ali', 'Yizheng']
# Tile Number: 944, Label: 3, Labelers: ['David', 'Yizheng']
# Tile Number: 158, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 711, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 234, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 142, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 1002, Label: 0, Labelers: ['David', 'Parth']
# Tile Number: 998, Label: 0, Labelers: ['David', 'Parth']
# Tile Number: 101, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 397, Label: 3, Labelers: ['Ali', 'David']
# Tile Number: 684, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 830, Label: 1, Labelers: ['Ali', 'David']
# Tile Number: 478, Label: 0, Labelers: ['Ali', 'Yizheng']
# Tile Number: 639, Label: 1, Labelers: ['Ali', 'Parth']
# Tile Number: 494, Label: 2, Labelers: ['Ali', 'Pankaj']
# Tile Number: 173, Label: 2, Labelers: ['David', 'Parth']
# Tile Number: 946, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 218, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 1020, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 788, Label: 0, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 917, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 199, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 677, Label: 4, Labelers: ['Krystal', 'Parth']
# Tile Number: 1031, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 958, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 232, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 576, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 934, Label: 3, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 1102, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 207, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 1064, Label: 0, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 573, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 741, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 377, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 430, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 730, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 629, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 565, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 135, Label: 0, Labelers: ['Parth', 'Yizheng']
# Tile Number: 163, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 766, Label: 0, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 1053, Label: 3, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 396, Label: 3, Labelers: ['Brian', 'Yizheng']
# Tile Number: 1059, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 174, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 123, Label: 0, Labelers: ['David', 'Dr.Lory']
# Tile Number: 980, Label: 1, Labelers: ['Ali', 'Pankaj']
# Tile Number: 248, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 418, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 1135, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 555, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 336, Label: 3, Labelers: ['Ali', 'Parth']
# Tile Number: 1150, Label: 0, Labelers: ['Brian', 'David']
# Tile Number: 1075, Label: 2, Labelers: ['Brian', 'Parth']
# Tile Number: 804, Label: 0, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 155, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 96, Label: 0, Labelers: ['David', 'Parth']
# Tile Number: 409, Label: 3, Labelers: ['Brian', 'David']
# Tile Number: 272, Label: 3, Labelers: ['Parth', 'Yizheng']
# Tile Number: 311, Label: 3, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 528, Label: 0, Labelers: ['Parth', 'Yizheng']
# Tile Number: 624, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 857, Label: 3, Labelers: ['Brian', 'Yizheng']
# Tile Number: 854, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 664, Label: 4, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 34, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 487, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 727, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 126, Label: 0, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 821, Label: 0, Labelers: ['Ali', 'Yizheng']
# Tile Number: 107, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 74, Label: 3, Labelers: ['Ali', 'Parth']
# Tile Number: 372, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 1095, Label: 0, Labelers: ['Pankaj', 'Parth']
# Tile Number: 605, Label: 4, Labelers: ['Ali', 'Brian']
# Tile Number: 641, Label: 1, Labelers: ['David', 'Pankaj']
# Tile Number: 239, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 1133, Label: 0, Labelers: ['Ali', 'Yizheng']
# Tile Number: 164, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 579, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 541, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 575, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 1058, Label: 0, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 692, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 1010, Label: 1, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 726, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 283, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 416, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 668, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 846, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 521, Label: 0, Labelers: ['David', 'Dr.Lory']
# Tile Number: 99, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 847, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 569, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 490, Label: 2, Labelers: ['Ali', 'Yizheng']
# Tile Number: 316, Label: 3, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 381, Label: 2, Labelers: ['David', 'Parth']
# Tile Number: 59, Label: 3, Labelers: ['Brian', 'Krystal']
# Tile Number: 956, Label: 1, Labelers: ['David', 'Yizheng']
# Tile Number: 686, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 137, Label: 4, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 439, Label: 3, Labelers: ['Parth', 'Yizheng']
# Tile Number: 1122, Label: 1, Labelers: ['Ali', 'Parth']
# Tile Number: 1089, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 94, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 955, Label: 4, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 975, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 943, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 1146, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 661, Label: 4, Labelers: ['Brian', 'David']
# Tile Number: 646, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 188, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 1065, Label: 0, Labelers: ['Brian', 'Parth']
# Tile Number: 657, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 129, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 612, Label: 3, Labelers: ['Ali', 'Yizheng']
# Tile Number: 557, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 28, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 356, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 1104, Label: 0, Labelers: ['David', 'Krystal']
# Tile Number: 752, Label: 3, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 642, Label: 0, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 9, Label: 2, Labelers: ['David', 'Parth']
# Tile Number: 343, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 1128, Label: 0, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 750, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 586, Label: 1, Labelers: ['David', 'Parth']
# Tile Number: 117, Label: 0, Labelers: ['David', 'Pankaj']
# Tile Number: 947, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 486, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 696, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 1113, Label: 2, Labelers: ['Brian', 'Krystal']
# Tile Number: 662, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 1097, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 898, Label: 0, Labelers: ['Parth', 'Yizheng']
# Tile Number: 1052, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 1025, Label: 0, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 166, Label: 3, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 1041, Label: 0, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 837, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 357, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 1114, Label: 0, Labelers: ['Ali', 'Yizheng']
# Tile Number: 915, Label: 4, Labelers: ['David', 'Dr.Lory']
# Tile Number: 516, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 566, Label: 4, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 687, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 226, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 1046, Label: 0, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 6, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 1141, Label: 1, Labelers: ['Ali', 'Pankaj']
# Tile Number: 509, Label: 0, Labelers: ['Brian', 'Parth']
# Tile Number: 398, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 52, Label: 3, Labelers: ['Pankaj', 'Parth']
# Tile Number: 1129, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 910, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 515, Label: 0, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 1063, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 818, Label: 0, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 1132, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 156, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 919, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 212, Label: 4, Labelers: ['David', 'Yizheng']
# Tile Number: 458, Label: 0, Labelers: ['Ali', 'Brian']
# Tile Number: 995, Label: 3, Labelers: ['David', 'Dr.Lory']
# Tile Number: 253, Label: 0, Labelers: ['Ali', 'Brian']
# Tile Number: 335, Label: 0, Labelers: ['David', 'Pankaj']
# Tile Number: 536, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 543, Label: 4, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 593, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 530, Label: 0, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 546, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 168, Label: 4, Labelers: ['David', 'Parth']
# Tile Number: 1143, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 23, Label: 3, Labelers: ['Brian', 'David']
# Tile Number: 808, Label: 3, Labelers: ['Ali', 'Parth']
# Tile Number: 991, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 483, Label: 2, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 242, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 222, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 554, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']

# %%
import json
from collections import Counter, defaultdict

# Load JSON files as before
def load_json(file_path):
    with open(file_path, 'r') as f:
        return json.load(f)

def transform_label(label):
    # Apply transformation with toleration
    if label == '1':
        return '0'
    elif label == '3':
        return '4'
    return label

def categorize_tiles_with_toleration(labeler_data):
    # Find common and uncommon tiles
    all_tiles = set(tile for data in labeler_data.values() for tile in data.keys())
    common_tiles = set.intersection(*[set(labeler.keys()) for labeler in labeler_data.values()])
    uncommon_tiles = all_tiles - common_tiles
    
    tile_agreement_dict = []

    # Process common tiles
    for tile in common_tiles:
        tile_labels = []
        labeler_by_label = defaultdict(list)
        
        for labeler, data in labeler_data.items():
            first_image = next(iter(data[tile]))
            # Transform label according to toleration rules
            label = transform_label(data[tile][first_image]['label'])
            tile_labels.append(label)
            labeler_by_label[label].append(labeler)
        
        # Count occurrences of each label for the tile
        label_count = Counter(tile_labels)

        # Check for labels agreed upon by more than 6 labelers
        for label, count in label_count.items():
            if count >= 6:
                tile_agreement_dict.append({
                    "tile_number": tile,
                    "label": label,
                    "labelers": labeler_by_label[label]
                })
                break  # Skip to the next tile if we find a label with more than 6 agreements

    # Process uncommon tiles
    for tile in uncommon_tiles:
        tile_labels = []
        labeler_by_label = defaultdict(list)
        
        for labeler, data in labeler_data.items():
            if tile in data:
                first_image = next(iter(data[tile]))
                # Transform label according to toleration rules
                label = transform_label(data[tile][first_image]['label'])
                tile_labels.append(label)
                labeler_by_label[label].append(labeler)
        
        # Count occurrences of each label for the tile
        label_count = Counter(tile_labels)

        # Check for labels agreed upon by exactly 2 labelers
        for label, count in label_count.items():
            if count == 2:
                tile_agreement_dict.append({
                    "tile_number": tile,
                    "label": label,
                    "labelers": labeler_by_label[label]
                })
                break  # Store only the first label with exactly 2 agreements

    return tile_agreement_dict

def process_labeler_files_with_toleration(file_paths):
    labeler_data = {}
    for file_path in file_paths:
        labeler_name = file_path.split('_')[0]
        labeler_data[labeler_name] = load_json(file_path)
    tile_agreement_dict = categorize_tiles_with_toleration(labeler_data)
    return tile_agreement_dict

# List your JSON file paths here
file_paths = ['Ali_labels.json', 
              'Brian_labels.json',
             'David_labels.json', 
             'Dr.Lory_labels.json',
             'Krystal_labels.json',
             'Pankaj_labels.json',
             'Parth_labels.json',
             'Yizheng_labels.json']

# Process files and get the dictionary of tiles with agreements after transformation
tile_agreement_dict = process_labeler_files_with_toleration(file_paths)

# Display the result
for entry in tile_agreement_dict:
    print(f"Tile Number: {entry['tile_number']}, Label: {entry['label']}, Labelers: {entry['labelers']}")
# Out:
# Tile Number: 1085, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1050, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 883, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 850, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 681, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 387, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Pankaj', 'Yizheng']
# Tile Number: 795, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 721, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 885, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 632, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 937, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Parth', 'Yizheng']
# Tile Number: 647, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 878, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth']
# Tile Number: 1117, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 529, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 476, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 61, Label: 0, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 635, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 607, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Yizheng']
# Tile Number: 852, Label: 0, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 31, Label: 0, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 302, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1110, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1009, Label: 0, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 703, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 695, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 116, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 923, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 597, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 470, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Parth', 'Yizheng']
# Tile Number: 325, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth']
# Tile Number: 495, Label: 2, Labelers: ['Ali', 'Brian', 'David', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 930, Label: 4, Labelers: ['Ali', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 438, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Parth', 'Yizheng']
# Tile Number: 281, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1123, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Parth', 'Yizheng']
# Tile Number: 136, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 290, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth']
# Tile Number: 577, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 43, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 217, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 783, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 522, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 737, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 671, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Yizheng']
# Tile Number: 967, Label: 4, Labelers: ['Ali', 'Brian', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1042, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 834, Label: 0, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 618, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 496, Label: 2, Labelers: ['Ali', 'Brian', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 194, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Yizheng']
# Tile Number: 1036, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1079, Label: 0, Labelers: ['Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Yizheng']
# Tile Number: 560, Label: 4, Labelers: ['Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 722, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 950, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 856, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 312, Label: 0, Labelers: ['Ali', 'David', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 189, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 685, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 863, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 359, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1032, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 619, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 701, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 50, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1043, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 369, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 389, Label: 4, Labelers: ['Ali', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Yizheng']
# Tile Number: 36, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 219, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Parth', 'Yizheng']
# Tile Number: 223, Label: 4, Labelers: ['Ali', 'Brian', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 552, Label: 4, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 308, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 812, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 1105, Label: 0, Labelers: ['Ali', 'Brian', 'David', 'Dr.Lory', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 464, Label: 2, Labelers: ['Ali', 'Brian', 'David', 'Krystal', 'Pankaj', 'Parth', 'Yizheng']
# Tile Number: 816, Label: 4, Labelers: ['Brian', 'David']
# Tile Number: 542, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 98, Label: 0, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 249, Label: 0, Labelers: ['David', 'Krystal']
# Tile Number: 525, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 482, Label: 2, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 132, Label: 0, Labelers: ['Brian', 'Parth']
# Tile Number: 139, Label: 4, Labelers: ['David', 'Pankaj']
# Tile Number: 740, Label: 0, Labelers: ['Ali', 'Krystal']
# Tile Number: 236, Label: 4, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 471, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 1004, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 481, Label: 0, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 309, Label: 2, Labelers: ['David', 'Krystal']
# Tile Number: 1047, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 314, Label: 0, Labelers: ['Brian', 'Pankaj']
# Tile Number: 666, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 826, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 296, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 759, Label: 0, Labelers: ['David', 'Dr.Lory']
# Tile Number: 224, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 411, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 561, Label: 4, Labelers: ['Ali', 'Brian']
# Tile Number: 344, Label: 0, Labelers: ['Parth', 'Yizheng']
# Tile Number: 21, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 399, Label: 4, Labelers: ['David', 'Yizheng']
# Tile Number: 427, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 264, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 266, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 1038, Label: 0, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 349, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 83, Label: 0, Labelers: ['David', 'Krystal']
# Tile Number: 600, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 1044, Label: 0, Labelers: ['Pankaj', 'Parth']
# Tile Number: 534, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 237, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 1021, Label: 0, Labelers: ['David', 'Pankaj']
# Tile Number: 518, Label: 2, Labelers: ['Krystal', 'Parth']
# Tile Number: 441, Label: 0, Labelers: ['Pankaj', 'Parth']
# Tile Number: 111, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 916, Label: 4, Labelers: ['Ali', 'Brian']
# Tile Number: 606, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 271, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 723, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 1005, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 914, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 715, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 615, Label: 4, Labelers: ['Ali', 'Brian']
# Tile Number: 1070, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 887, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 643, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 793, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 978, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 623, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 144, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 774, Label: 0, Labelers: ['David', 'Dr.Lory']
# Tile Number: 999, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 7, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 965, Label: 4, Labelers: ['Brian', 'David']
# Tile Number: 836, Label: 0, Labelers: ['David', 'Yizheng']
# Tile Number: 346, Label: 4, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 688, Label: 4, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 1111, Label: 0, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 567, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 421, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 540, Label: 4, Labelers: ['Ali', 'Brian']
# Tile Number: 633, Label: 4, Labelers: ['Brian', 'David']
# Tile Number: 663, Label: 4, Labelers: ['David', 'Pankaj']
# Tile Number: 851, Label: 0, Labelers: ['Pankaj', 'Parth']
# Tile Number: 364, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 604, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 631, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 500, Label: 2, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 447, Label: 4, Labelers: ['David', 'Parth']
# Tile Number: 358, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 362, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 725, Label: 4, Labelers: ['Krystal', 'Parth']
# Tile Number: 24, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 751, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 1067, Label: 0, Labelers: ['David', 'Pankaj']
# Tile Number: 697, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 859, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 214, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 450, Label: 4, Labelers: ['Krystal', 'Parth']
# Tile Number: 608, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 276, Label: 0, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 102, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 1140, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 73, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 5, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 4, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 513, Label: 0, Labelers: ['David', 'Dr.Lory']
# Tile Number: 520, Label: 0, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 1127, Label: 0, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 431, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 602, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 328, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 182, Label: 0, Labelers: ['Ali', 'Brian']
# Tile Number: 779, Label: 0, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 1092, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 171, Label: 4, Labelers: ['David', 'Krystal']
# Tile Number: 556, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 82, Label: 0, Labelers: ['Ali', 'Krystal']
# Tile Number: 244, Label: 0, Labelers: ['Ali', 'Yizheng']
# Tile Number: 124, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 798, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 813, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 320, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 1056, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 172, Label: 4, Labelers: ['Krystal', 'Parth']
# Tile Number: 918, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 796, Label: 0, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 404, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 105, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 902, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 932, Label: 4, Labelers: ['Brian', 'David']
# Tile Number: 131, Label: 0, Labelers: ['David', 'Parth']
# Tile Number: 108, Label: 0, Labelers: ['Brian', 'Yizheng']
# Tile Number: 380, Label: 2, Labelers: ['Brian', 'David']
# Tile Number: 563, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 1108, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 924, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 1149, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 195, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 428, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 1116, Label: 0, Labelers: ['Brian', 'Pankaj']
# Tile Number: 1037, Label: 0, Labelers: ['Pankaj', 'Parth']
# Tile Number: 925, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 1057, Label: 0, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 407, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 227, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 289, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 436, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 884, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 153, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 235, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 1018, Label: 0, Labelers: ['Pankaj', 'Parth']
# Tile Number: 539, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 355, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 352, Label: 4, Labelers: ['David', 'Krystal']
# Tile Number: 319, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 922, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 1015, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 1125, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 127, Label: 0, Labelers: ['David', 'Parth']
# Tile Number: 1098, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 415, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 988, Label: 0, Labelers: ['David', 'Parth']
# Tile Number: 1049, Label: 0, Labelers: ['Brian', 'David']
# Tile Number: 658, Label: 4, Labelers: ['David', 'Parth']
# Tile Number: 208, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 644, Label: 0, Labelers: ['Ali', 'Brian']
# Tile Number: 192, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 193, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 288, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 927, Label: 4, Labelers: ['Krystal', 'Parth']
# Tile Number: 921, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 85, Label: 0, Labelers: ['Ali', 'Brian']
# Tile Number: 270, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 1062, Label: 0, Labelers: ['Ali', 'Brian']
# Tile Number: 758, Label: 0, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 160, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 255, Label: 0, Labelers: ['Ali', 'Krystal']
# Tile Number: 231, Label: 4, Labelers: ['Brian', 'David']
# Tile Number: 626, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 911, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 449, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 110, Label: 2, Labelers: ['Ali', 'Parth']
# Tile Number: 743, Label: 2, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 331, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 1035, Label: 0, Labelers: ['Brian', 'David']
# Tile Number: 882, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 292, Label: 0, Labelers: ['Ali', 'Yizheng']
# Tile Number: 733, Label: 0, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 797, Label: 0, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 895, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 578, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 984, Label: 4, Labelers: ['David', 'Pankaj']
# Tile Number: 519, Label: 0, Labelers: ['David', 'Krystal']
# Tile Number: 571, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 996, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 1134, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 819, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 948, Label: 4, Labelers: ['Ali', 'Brian']
# Tile Number: 251, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 1077, Label: 0, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 440, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 739, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 269, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 467, Label: 2, Labelers: ['Brian', 'Yizheng']
# Tile Number: 1040, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 1088, Label: 0, Labelers: ['Parth', 'Yizheng']
# Tile Number: 789, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 794, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 14, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 568, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 1071, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 838, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 33, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 966, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 625, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 1099, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 209, Label: 4, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 907, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 183, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 391, Label: 0, Labelers: ['Brian', 'Yizheng']
# Tile Number: 705, Label: 0, Labelers: ['David', 'Pankaj']
# Tile Number: 327, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 1007, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 57, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 679, Label: 4, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 75, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 820, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 121, Label: 0, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 12, Label: 4, Labelers: ['Krystal', 'Parth']
# Tile Number: 1076, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 118, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 732, Label: 0, Labelers: ['Pankaj', 'Parth']
# Tile Number: 832, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 670, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 551, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 742, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 1106, Label: 0, Labelers: ['Ali', 'Brian']
# Tile Number: 48, Label: 0, Labelers: ['David', 'Dr.Lory']
# Tile Number: 492, Label: 2, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 848, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 748, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 517, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 761, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 479, Label: 0, Labelers: ['Brian', 'David']
# Tile Number: 822, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 225, Label: 4, Labelers: ['David', 'Dr.Lory']
# Tile Number: 461, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 301, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 92, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 213, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 297, Label: 0, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 70, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 493, Label: 0, Labelers: ['David', 'Dr.Lory']
# Tile Number: 10, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 904, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 128, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 29, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 54, Label: 2, Labelers: ['Brian', 'Krystal']
# Tile Number: 100, Label: 0, Labelers: ['Brian', 'Parth']
# Tile Number: 473, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 332, Label: 4, Labelers: ['David', 'Pankaj']
# Tile Number: 973, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 765, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 1034, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 691, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 210, Label: 4, Labelers: ['Brian', 'David']
# Tile Number: 322, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 306, Label: 0, Labelers: ['Brian', 'Yizheng']
# Tile Number: 204, Label: 0, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 190, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 1003, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 233, Label: 4, Labelers: ['Ali', 'Brian']
# Tile Number: 558, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 250, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 1081, Label: 0, Labelers: ['Parth', 'Yizheng']
# Tile Number: 474, Label: 0, Labelers: ['David', 'Parth']
# Tile Number: 1051, Label: 0, Labelers: ['Ali', 'Krystal']
# Tile Number: 784, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 424, Label: 0, Labelers: ['Brian', 'Parth']
# Tile Number: 114, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 724, Label: 4, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 535, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 993, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 511, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 413, Label: 2, Labelers: ['David', 'Parth']
# Tile Number: 616, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 16, Label: 4, Labelers: ['David', 'Dr.Lory']
# Tile Number: 1118, Label: 0, Labelers: ['Brian', 'David']
# Tile Number: 71, Label: 4, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 104, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 831, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 603, Label: 4, Labelers: ['David', 'Krystal']
# Tile Number: 855, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 196, Label: 4, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 1017, Label: 0, Labelers: ['David', 'Yizheng']
# Tile Number: 840, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 485, Label: 0, Labelers: ['David', 'Yizheng']
# Tile Number: 339, Label: 0, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 700, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 130, Label: 2, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 734, Label: 0, Labelers: ['David', 'Yizheng']
# Tile Number: 1096, Label: 0, Labelers: ['Parth', 'Yizheng']
# Tile Number: 786, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 614, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 622, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 719, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 1045, Label: 0, Labelers: ['Ali', 'Krystal']
# Tile Number: 373, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 291, Label: 0, Labelers: ['Brian', 'Pankaj']
# Tile Number: 842, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 175, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 125, Label: 0, Labelers: ['David', 'Krystal']
# Tile Number: 585, Label: 0, Labelers: ['Ali', 'Brian']
# Tile Number: 216, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 903, Label: 4, Labelers: ['David', 'Yizheng']
# Tile Number: 1138, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 1011, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 78, Label: 0, Labelers: ['David', 'Yizheng']
# Tile Number: 636, Label: 4, Labelers: ['Ali', 'Brian']
# Tile Number: 256, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 211, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 462, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 599, Label: 4, Labelers: ['Ali', 'Brian']
# Tile Number: 667, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 890, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 944, Label: 4, Labelers: ['David', 'Yizheng']
# Tile Number: 158, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 538, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 103, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 711, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 240, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 234, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 142, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 1002, Label: 0, Labelers: ['David', 'Parth']
# Tile Number: 998, Label: 0, Labelers: ['David', 'Parth']
# Tile Number: 101, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 400, Label: 4, Labelers: ['David', 'Yizheng']
# Tile Number: 334, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 397, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 684, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 830, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 478, Label: 0, Labelers: ['Ali', 'Yizheng']
# Tile Number: 639, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 494, Label: 2, Labelers: ['Ali', 'Pankaj']
# Tile Number: 173, Label: 2, Labelers: ['David', 'Parth']
# Tile Number: 1014, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 946, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 218, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 1020, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 475, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 179, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 788, Label: 0, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 917, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 350, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 199, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 677, Label: 4, Labelers: ['Krystal', 'Parth']
# Tile Number: 1031, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 958, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 232, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 576, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 97, Label: 0, Labelers: ['Pankaj', 'Parth']
# Tile Number: 934, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 1102, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 207, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 1064, Label: 0, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 390, Label: 0, Labelers: ['Ali', 'Brian']
# Tile Number: 573, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 741, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 610, Label: 4, Labelers: ['David', 'Krystal']
# Tile Number: 377, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 430, Label: 4, Labelers: ['Ali', 'Krystal']
# Tile Number: 730, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 8, Label: 4, Labelers: ['David', 'Parth']
# Tile Number: 267, Label: 4, Labelers: ['Krystal', 'Parth']
# Tile Number: 972, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 629, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 565, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 371, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 135, Label: 0, Labelers: ['Parth', 'Yizheng']
# Tile Number: 163, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 766, Label: 0, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 1053, Label: 4, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 396, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 1059, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 174, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 123, Label: 0, Labelers: ['David', 'Dr.Lory']
# Tile Number: 596, Label: 4, Labelers: ['David', 'Yizheng']
# Tile Number: 839, Label: 0, Labelers: ['David', 'Pankaj']
# Tile Number: 980, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 248, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 968, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 881, Label: 4, Labelers: ['David', 'Krystal']
# Tile Number: 418, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 1135, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 841, Label: 0, Labelers: ['David', 'Dr.Lory']
# Tile Number: 555, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 395, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 336, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 1150, Label: 0, Labelers: ['Brian', 'David']
# Tile Number: 630, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 1075, Label: 2, Labelers: ['Brian', 'Parth']
# Tile Number: 1121, Label: 0, Labelers: ['David', 'Pankaj']
# Tile Number: 11, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 287, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 804, Label: 0, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 507, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 150, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 155, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 88, Label: 0, Labelers: ['David', 'Yizheng']
# Tile Number: 261, Label: 0, Labelers: ['Brian', 'Yizheng']
# Tile Number: 96, Label: 0, Labelers: ['David', 'Parth']
# Tile Number: 409, Label: 4, Labelers: ['Brian', 'David']
# Tile Number: 272, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 502, Label: 0, Labelers: ['Krystal', 'Parth']
# Tile Number: 311, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 279, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 528, Label: 0, Labelers: ['Parth', 'Yizheng']
# Tile Number: 624, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 857, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 854, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 664, Label: 4, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 417, Label: 4, Labelers: ['David', 'Dr.Lory']
# Tile Number: 34, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 487, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 727, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 126, Label: 0, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 821, Label: 0, Labelers: ['Ali', 'Yizheng']
# Tile Number: 107, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 74, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 372, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 1095, Label: 0, Labelers: ['Pankaj', 'Parth']
# Tile Number: 605, Label: 4, Labelers: ['Ali', 'Brian']
# Tile Number: 945, Label: 4, Labelers: ['David', 'Parth']
# Tile Number: 641, Label: 0, Labelers: ['David', 'Pankaj']
# Tile Number: 549, Label: 4, Labelers: ['David', 'Krystal']
# Tile Number: 239, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 1133, Label: 0, Labelers: ['Ali', 'Yizheng']
# Tile Number: 997, Label: 4, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 164, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 867, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 579, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 541, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 575, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 1058, Label: 0, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 692, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 1010, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 726, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 283, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 416, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 668, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 140, Label: 4, Labelers: ['Krystal', 'Parth']
# Tile Number: 846, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 521, Label: 0, Labelers: ['David', 'Dr.Lory']
# Tile Number: 99, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 847, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 569, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 490, Label: 2, Labelers: ['Ali', 'Yizheng']
# Tile Number: 1078, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 316, Label: 4, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 381, Label: 2, Labelers: ['David', 'Parth']
# Tile Number: 337, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 149, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 59, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 956, Label: 0, Labelers: ['David', 'Yizheng']
# Tile Number: 866, Label: 4, Labelers: ['David', 'Dr.Lory']
# Tile Number: 686, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 307, Label: 0, Labelers: ['Brian', 'Yizheng']
# Tile Number: 137, Label: 4, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 274, Label: 4, Labelers: ['David', 'Yizheng']
# Tile Number: 439, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 1122, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 145, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 1089, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 94, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 955, Label: 4, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 975, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 943, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 1146, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 661, Label: 4, Labelers: ['Brian', 'David']
# Tile Number: 646, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 392, Label: 0, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 188, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 1065, Label: 0, Labelers: ['Brian', 'Parth']
# Tile Number: 410, Label: 0, Labelers: ['David', 'Yizheng']
# Tile Number: 657, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 129, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 1072, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 612, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 557, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 28, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 356, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 1104, Label: 0, Labelers: ['David', 'Krystal']
# Tile Number: 594, Label: 0, Labelers: ['David', 'Dr.Lory']
# Tile Number: 752, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 642, Label: 0, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 9, Label: 2, Labelers: ['David', 'Parth']
# Tile Number: 343, Label: 4, Labelers: ['Ali', 'Yizheng']
# Tile Number: 1128, Label: 0, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 304, Label: 4, Labelers: ['David', 'Krystal']
# Tile Number: 750, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 141, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 586, Label: 0, Labelers: ['David', 'Parth']
# Tile Number: 117, Label: 0, Labelers: ['David', 'Pankaj']
# Tile Number: 865, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 1115, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 947, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 486, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 696, Label: 4, Labelers: ['Brian', 'Yizheng']
# Tile Number: 1113, Label: 2, Labelers: ['Brian', 'Krystal']
# Tile Number: 662, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 1022, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 154, Label: 4, Labelers: ['Brian', 'Pankaj']
# Tile Number: 273, Label: 4, Labelers: ['David', 'Yizheng']
# Tile Number: 942, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 1097, Label: 0, Labelers: ['Ali', 'David']
# Tile Number: 898, Label: 0, Labelers: ['Parth', 'Yizheng']
# Tile Number: 1052, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 1025, Label: 0, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 166, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 669, Label: 4, Labelers: ['David', 'Krystal']
# Tile Number: 1041, Label: 0, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 837, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 357, Label: 4, Labelers: ['Parth', 'Yizheng']
# Tile Number: 19, Label: 4, Labelers: ['Ali', 'David']
# Tile Number: 532, Label: 0, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 1114, Label: 0, Labelers: ['Ali', 'Yizheng']
# Tile Number: 202, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 310, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 915, Label: 4, Labelers: ['David', 'Dr.Lory']
# Tile Number: 516, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 566, Label: 4, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 687, Label: 4, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 1137, Label: 0, Labelers: ['Brian', 'Pankaj']
# Tile Number: 928, Label: 0, Labelers: ['Brian', 'Krystal']
# Tile Number: 226, Label: 4, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 1046, Label: 0, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 6, Label: 4, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 1141, Label: 0, Labelers: ['Ali', 'Pankaj']
# Tile Number: 509, Label: 0, Labelers: ['Brian', 'Parth']
# Tile Number: 710, Label: 4, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 398, Label: 4, Labelers: ['Krystal', 'Pankaj']
# Tile Number: 52, Label: 4, Labelers: ['Pankaj', 'Parth']
# Tile Number: 1129, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 910, Label: 0, Labelers: ['Ali', 'Parth']
# Tile Number: 515, Label: 0, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 1063, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 818, Label: 0, Labelers: ['Dr.Lory', 'Pankaj']
# Tile Number: 162, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 1132, Label: 0, Labelers: ['Pankaj', 'Yizheng']
# Tile Number: 156, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 919, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 212, Label: 4, Labelers: ['David', 'Yizheng']
# Tile Number: 458, Label: 0, Labelers: ['Ali', 'Brian']
# Tile Number: 1073, Label: 0, Labelers: ['Brian', 'Yizheng']
# Tile Number: 995, Label: 4, Labelers: ['David', 'Dr.Lory']
# Tile Number: 253, Label: 0, Labelers: ['Ali', 'Brian']
# Tile Number: 335, Label: 0, Labelers: ['David', 'Pankaj']
# Tile Number: 536, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 543, Label: 4, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 345, Label: 0, Labelers: ['Pankaj', 'Parth']
# Tile Number: 593, Label: 4, Labelers: ['Brian', 'Krystal']
# Tile Number: 394, Label: 0, Labelers: ['Brian', 'Parth']
# Tile Number: 530, Label: 0, Labelers: ['Ali', 'Dr.Lory']
# Tile Number: 90, Label: 0, Labelers: ['Brian', 'Pankaj']
# Tile Number: 546, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 454, Label: 0, Labelers: ['David', 'Krystal']
# Tile Number: 168, Label: 4, Labelers: ['David', 'Parth']
# Tile Number: 1143, Label: 0, Labelers: ['Dr.Lory', 'Parth']
# Tile Number: 324, Label: 0, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 433, Label: 4, Labelers: ['Krystal', 'Yizheng']
# Tile Number: 941, Label: 4, Labelers: ['Dr.Lory', 'Krystal']
# Tile Number: 706, Label: 4, Labelers: ['Brian', 'David']
# Tile Number: 654, Label: 0, Labelers: ['Ali', 'Yizheng']
# Tile Number: 23, Label: 4, Labelers: ['Brian', 'David']
# Tile Number: 808, Label: 4, Labelers: ['Ali', 'Parth']
# Tile Number: 991, Label: 4, Labelers: ['Brian', 'Parth']
# Tile Number: 483, Label: 2, Labelers: ['Brian', 'Dr.Lory']
# Tile Number: 242, Label: 4, Labelers: ['Ali', 'Pankaj']
# Tile Number: 222, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']
# Tile Number: 505, Label: 0, Labelers: ['David', 'Pankaj']
# Tile Number: 554, Label: 4, Labelers: ['Dr.Lory', 'Yizheng']

# %%
tile_label_agreement_tol = tile_agreement_dict

# %%
tile_agreement_dict_without_2 = []

for entry in tile_label_agreement_tol:

    if entry['label'] != '2':

        tile_agreement_dict_without_2.append({
                    "tile_number": entry['tile_number'],
                    "label": entry['label'],
                    "labelers": entry['labelers']
                })

# %%
len(tile_agreement_dict_without_2)
# Out:
# 621

# %%
import json

data_dict = {entry["tile_number"]: {"label": entry["label"], "labelers": entry["labelers"]} for entry in tile_agreement_dict_without_2}

# Save to JSON file
with open('GT_L6_Tol.json', 'w') as json_file:
    json.dump(data_dict, json_file, indent=4)

# %%
with open('GT_L6_Tol.json', 'r') as json_file:
    data_dict = json.load(json_file)

# Initialize counters
count_4 = 0
count_0 = 0

# Iterate over the data to count labels
for tile_info in data_dict.values():
    label = tile_info["label"]
    if label == '4':
        count_4 += 1
    elif label == '0':
        count_0 += 1

# Print the results
print(f"Number of tiles with label 4: {count_4}")
print(f"Number of tiles with label 0: {count_0}")
# Out:
# Number of tiles with label 4: 354
# Number of tiles with label 0: 267
